# %% [markdown]
# <a href="https://colab.research.google.com/github/kth24680/HowToDeep_Learning/blob/master/TEST01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/kth24680/HowToDeep_Learning.git
# Out:
# fatal: destination path 'HowToDeep_Learning' already exists and is not an empty directory.

# %%
ls -ltr
# Out:
# total 12
# drwxr-xr-x 1 root root 4096 Mar 18 16:23 sample_data/
# drwx------ 3 root root 4096 Mar 29 08:59 drive/
# drwxr-xr-x 4 root root 4096 Mar 29 09:00 HowToDeep_Learning/

# %%
my_list = [10, 'hello list', 20]
print(my_list[1])
# Out:
# hello list

# %%
my_list_2 = [[10,20,30],[40,50,60]]
print(my_list_2[1][1])
# Out:
# 50

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.18.2

# %%
#1.array() 함수로 2차원 배멸 만들기
my_arr = np.array([[10,20,30],[40,50,60]])
print(my_arr)
# Out:
# [[10 20 30]
#  [40 50 60]]

# %%
#2.type()함수로 넘파이 배열인지 확인하기
type(my_arr)
# Out:
# numpy.ndarray

# %%
#3.넘파이 배열에서 요소 선택하기
my_arr[0][2]
# Out:
# 30

# %%
#4. 넘파이 내장 함수 사용하기 
np.sum(my_arr)
# Out:
# 210

# %%
#맷플롯립(Matplotlib)으로 그래프 그리기
import matplotlib.pyplot as plt

# %%
#1.선 그래프 그리기
plt.plot([1,2,3,4,5],[1,4,9,16,25])
plt.show()

# %%
#2.산점도 그리기
plt.scatter([1,2,3,4,5],[1,4,9,16,25])
plt.show()

# %%
#3. 넘파이 배열로 산점도 그리기
x = np.random.randn(1000)
y = np.random.randn(1000)
plt.scatter(x,y)
plt.show()
